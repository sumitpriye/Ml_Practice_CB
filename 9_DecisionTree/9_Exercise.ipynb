# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis ='columns', inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
input_features = df.drop(['Survived'], axis = 1)

# %%
input_features
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
target = df['Survived']

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
input_features.describe
# Out:
# <bound method NDFrame.describe of      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]>

# %%
input_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    object
#  2   Age     714 non-null    float64
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 28.0+ KB

# %%
#input_features['Age'].fillna(input_features['Age'].mode(),inplace=True)

# %%
#input_features.Age = input_features.Age.fillna(input_features.Age.median())

# %%
input_features['Age'].fillna(input_features['Age'].mode()[0],inplace=True)

# %%
input_features
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female  24.0  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
input_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  891 non-null    int64
#  1   Sex     891 non-null    object
#  2   Age     891 non-null    float64
#  3   Fare    891 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 28.0+ KB

# %%
input_features['Age'].mode()[0]
# Out:
# 24.0

# %%
input_features.Age.median()
# Out:
# 24.0

# %%
input_features.Age.mean()
# Out:
# 28.566969696969696

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
input_features['Sex']=le.fit_transform(input_features['Sex'])

# %%
input_features #1-male 0-female
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0  24.0  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Survived
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
target.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(input_features,target,test_size=0.2,random_state=100)

# %%
X_train
# Out:
#      Pclass  Sex   Age      Fare
# 408       3    1  21.0    7.7750
# 480       3    1   9.0   46.9000
# 510       3    1  29.0    7.7500
# 609       1    0  40.0  153.4625
# 547       2    1  24.0   13.8625
# ..      ...  ...   ...       ...
# 855       3    0  18.0    9.3500
# 871       1    0  47.0   52.5542
# 835       1    0  39.0   83.1583
# 792       3    0  24.0   69.5500
# 520       1    0  30.0   93.5000
#
# [712 rows x 4 columns]

# %%
X_test
# Out:
#      Pclass  Sex   Age     Fare
# 205       3    0   2.0  10.4625
# 44        3    0  19.0   7.8792
# 821       3    1  27.0   8.6625
# 458       2    0  50.0  10.5000
# 795       2    1  39.0  13.0000
# ..      ...  ...   ...      ...
# 247       2    0  24.0  14.5000
# 259       2    0  50.0  26.0000
# 353       3    1  25.0  17.8000
# 783       3    1  24.0  23.4500
# 852       3    0   9.0  15.2458
#
# [179 rows x 4 columns]

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(input_features,target)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_test,y_test)
# Out:
# 0.9720670391061452

# %%
clf.score(X_train,y_train)
# Out:
# 0.9803370786516854
